# %%
import pandas as pd
import numpy as np
import pickle
import csv
import nltk
nltk.download('punkt')
nltk.download('stopwords')
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from scipy.spatial.distance import cosine



from collections import defaultdict
from collections import Counter
from math import log
# Out:
# [nltk_data] Downloading package punkt to /Users/miguel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/miguel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Import data

# %%
texas1 = pd.read_csv("data/Airbnb_Texas_Rentals.csv")
texas1 = texas1.drop(['Unnamed: 0'], axis=1)

# %%
#pd.set_option('expand_frame_repr',False)
texas1.head()
# Out:
#   average_rate_per_night bedrooms_count         city date_of_listing  \
# 0                    $27              2       Humble        May 2016
# 1                   $149              4  San Antonio   November 2010
# 2                    $59              1      Houston    January 2017
# 3                    $60              1        Bryan   February 2016
# 4                    $75              2   Fort Worth   February 2017
#
#                                          description   latitude  longitude  \
# 0  Welcome to stay in private room with queen bed...  30.020138 -95.293996
# 1  Stylish, fully remodeled home in upscale NW – ...  29.503068 -98.447688
# 2  'River house on island close to the city' \nA ...  29.829352 -95.081549
# 3  Private bedroom in a cute little home situated...  30.637304 -96.337846
# 4  Welcome to our original 1920's home. We recent...  32.747097 -97.286434
#
#                                                title  \
# 0    2 Private rooms/bathroom 10min from IAH airport
# 1  Unique Location! Alamo Heights - Designer Insp...
# 2                          River house near the city
# 3                       Private Room Close to Campus
# 4                                          The Porch
#
#                                                  url
# 0  https://www.airbnb.com/rooms/18520444?location...
# 1  https://www.airbnb.com/rooms/17481455?location...
# 2  https://www.airbnb.com/rooms/16926307?location...
# 3  https://www.airbnb.com/rooms/11839729?location...
# 4  https://www.airbnb.com/rooms/17325114?location...

# %% [markdown]
# # Create docuemnts as tsv file

# %%
path1 = 'data/docs/'
path2 = '.tsv'
stemmed_path='data/tokenized_docs/'
sp = string.punctuation+'“”–’'

# %%
def remove_step(doc):
    """
    takes as input the string of the document
    removes stopwords, punctuation and makes stemming 
    """
    
    # check if it's a nan value 

    if isinstance(doc, float):
        return str(doc)
    
    doc=doc.replace("\\n", " ")
    # punctuations
    doc = [ c if c not in sp else " "  for c in doc ]
    doc = ''.join(doc)
    # stopwords
    doc = [ word for word in doc.split() if word.lower() not in stopwords.words('english') ]
    doc = ' '.join(doc)
    
    # stemming
    ps = PorterStemmer()
    words = word_tokenize(doc)
    
    w_lst = []
    for w in words:
        w_lst.append(ps.stem(w))
    
    # something else
    
    return ' '.join(w_lst)

# %%
def save_obj(obj, name):
    with open('data/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open('data/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
def preprocessing(data):
    n=len(data)

    for i in range(n):
        with open(path1 + 'doc_'+ str(i) + '.tsv', 'w') as doc:
            a = csv.writer(doc, delimiter='\t')
            a.writerow([data.iloc[i]['average_rate_per_night'],data.iloc[i]['bedrooms_count'] 
                      ,data.iloc[i]['city'] ,data.iloc[i]['date_of_listing'], data.iloc[i]['description']
                      ,data.iloc[i]['latitude'],data.iloc[i]['longitude'] ,data.iloc[i]['title'] ,data.iloc[i]['url']])

    return

def create_vocabulary_and_ii1 (data):
    n = len(data)
    vocabulary = {}
    ii1 = {}    
    cnt = 0
    
    for i in range(n):
        # creating a tokenized string with title and description
        tokenized_str = (remove_step(data.iloc[i]['title']) + ' ' 
                                     + remove_step(data.iloc[i]['description']))

        # creating the dictionary
        for term in tokenized_str.split(' '):
            if term in vocabulary.keys():
                term_id = vocabulary[term]
            else:
                vocabulary[term] = cnt
                term_id = cnt
                cnt+=1

            if term_id not in ii1.keys():
                ii1[term_id] = ['doc_'+str(i)]
            else:
                lista = ii1[term_id]
                document = 'doc_'+str(i)
                if document in lista:
                    continue
                else:        
                    ii1[term_id].append('doc_'+str(i))

    # store vocabulary in pickle format
    save_obj(vocabulary, 'vocabulary')
    save_obj(ii1, 'inverted_index_1')
    return

# %%
#create_vocabulary and inverted index 1 (for the first search engine)

#create_vocabulary_and_ii1(texas1)

# %%
# do not run if you don't want to waste time :-D 
#preprocessing(texas1)

# %%
def search_engine_1(query): 
    
    query = remove_step(query)
    query = list(set(query.split(' ')))
    
    lst_of_lst=[]
    
    vocabulary = load_obj('vocabulary')
    ii1 = load_obj('inverted_index_1')
    
    for w in query:
        if w not in vocabulary:
            print('No results')
            return
        i = vocabulary[w]
        lst_of_lst.append(ii1[i])


    doc_list = set.intersection(*[set(sublist) for sublist in lst_of_lst])
    doc_list = list(doc_list)
    dl = len(doc_list)
    
    if dl ==0:
        print('No results')
        return

    list_for_df=[]
    for i in range(dl):
        with open ("data/docs/" + doc_list[i] + '.tsv') as doc:
            row = doc.read()
            lst = row.split('\t')
            lst = [lst[7],lst[4],lst[2],lst[8]]
            list_for_df.append(lst)
        
    df=pd.DataFrame(list_for_df, columns=['Title', 'Description', 'City', 'Url'])
    
    return df.head(5)

# %%
search_engine_1('private room bathroom')
# Out:
#                                                Title  \
# 0  Master room near SMU/Downtown/DLA AP/Train Sta...
# 1  10 MIN WALK TO NRG: Private Room! Near Med Center
# 2                             Cool and Updated Space
# 3                 The Stuttgart Room (Schaefer Haus)
# 4                                   G's Resort V 2.2
#
#                                          Description       City  \
# 0  1 PRIVATE clean comfy Master bedroom and an en...     Dallas
# 1  Located less than a mile from NRG Stadium, thi...    Houston
# 2  Cozy and private bedroom and bathroom located ...     Austin
# 3  This is the Stuttgart Room of the Schaefer Hau...  Galveston
# 4  Convenient central location near SMU with priv...     Dallas
#
#                                                  Url
# 0  https://www.airbnb.com/rooms/12186608?location...
# 1  https://www.airbnb.com/rooms/16649137?location...
# 2  https://www.airbnb.com/rooms/14930777?location...
# 3  https://www.airbnb.com/rooms/16917205?location...
# 4  https://www.airbnb.com/rooms/8341908?location=...

# %%
#ii2 = dict_with_tf(texas1)

# %%
#temp = ii2

# %%
############ SPARK
for key,values in ii2.items():
    
    newlst = sc.parallelize(values)
    
    newlst = newlst.reduceByKey(lambda a,b:a+b)
    
    ii2[key] = newlst.take(len(values))

# %% [markdown]
#     II with TF:
#     Taking each list for each term in the inverted index,
#     we wanted to find the occurrencies for that term in each document.
#     Thus, we created the inverted index with every document appended inside the value of each
#     term (the key of the dictionary),
#     and using in a loop the reduce_doc_list method.
#     In this method we reduced the repetitions of the same docs in each list, summing them.
#     We created the

# %%
def reduce_doc_list(doc_list):
    """
    function called by dict_TFIDF
    
    It reduces the list of documents into a list 
    of tuple with doc_id and its occurencies
    
    input:
    - list 
    output:
    - list 
    """
    tf_term_i = Counter(doc_list)
    doc_tf_lst = []
    doc_tf_lst = [tuple([key,value]) for key,value in tf_term_i.items()]
    return doc_tf_lst

def compute_ii2_TFIDF(ii2,n):
    """
    compute the ii2_TFIDF
    input:
    - inverted index matrix (with TF)
    - number of documents
    output:
    - ii2 
    """
    for key, value in ii2.items():
        N = len(value)
        new_list = []
        for item in value:
            new_list.append(tuple([item[0], round(float(item[1])* log(n/N),3)]))
            
        ii2[key] = new_list
    return ii2

# %%
def dict_with_TFIDF(data):
    """
    creates the TFIDF inverted index as dict
    and store it into a pickle file
    input:
    - data
    """
    vocabulary = load_obj('vocabulary')
    n = len(data)
    
    ii2 = defaultdict(list)
    
    for i in range(n):
        tokenized_str = (remove_step(data.iloc[i]['title']) + ' ' 
                                     + remove_step(data.iloc[i]['description']))
    
        for term in tokenized_str.split(' '):
            doc_name = 'doc_%s'%i
            ii2[vocabulary[term]].append(doc_name)
            
    
    for key,value in ii2.items():
        ii2[key] = reduce_doc_list(value)
    
    ii2 = compute_ii2_TFIDF(ii2,n)
    save_obj(ii2,'inverted_index_TFIDF')
    return

# %%
import time
start = time.time()
dict_with_TFIDF(texas1)
print (time.time()-start)

# %%
ii2 = load_obj('inverted_index_TFIDF')

# %%
scrauso = {
    0: [('doc_0', 2), ('doc_1', 1), ('doc_3', 1), ('doc_7', 1)],
    1: [('doc_0', 2), ('doc_7', 1)]
       }

# %%
temp = ii2
temp = compute_ii2_TFIDF(temp, len(texas1))

# %%
temp = {
    0: ii2[0][0:5],
    1: ii2[1][:5],
    2: ii2[2][:5],
    3: ii2[3][:5]
}

# %%
# make the query
q = [1,2,3]

# %%
ii1 = load_obj('inverted_index_1')
ii1 = {i}

# %%
# initialize doc
docs = []

# %%
for i, values in enumerate(ii1.values()):
    if i == 0:
        docs += values
        docs = set(docs)
    else:
        docs.intersection(set(values))

# %%
#for values in ii1.values():
#    print(values)

# %%
def take_docs(inv_ind_1):
    #we need to take the indices from the numpy array - tricky
    
    docs = set.intersection(*[set(inv_ind_1[i]) for i in inv_ind_1])
    docs = list(docs)
    
    return docs
ᐧ

# %%
print(len(min(ii2.values())))

# %%
new_dict = {query:ii1[query] for query in q}

# %%
docs = []

for i,values in enumerate(new_dict.values()):
    
    if i == 0:
        docs = set(values)
    else:
        docs.intersection(values)
    
docs = list(set(first_set))

# %%
# doc
docs = filter(lambda x: x)

# %%
ii2 = load_obj('inverted_index_TFIDF')

# %%
ii2 = {query:ii2[query] for query in q}

# %%
len(ii2)

# %%
len(min(ii2.values()))

# %%
q = [1,2,3]
ii2 = load_obj('inverted_index_TFIDF')

new_dict = {query:ii1[query] for query in q}
rank_lst = []
query_a = np.ones(len(array), dtype=float)

for doc_id in docs:
    array = []
    for lst_value in ii2.values():
        array += (filter(lambda x:x[0]==doc_id, lst_value))
    
    if len(array) == 3:
        array = np.array([x[1] for x in array])
        rank_lst.append(tuple([doc_id,round(1-cosine(array,ways),3)]))

# %%
rank_lst.sort(key = lambda x:x[1],reverse=True)

# %%
#rank_lst

# %%
ways = np.ones(len(array), dtype=float)

# %%
from scipy.spatial.distance import cosine

# %%
np.dot(array,ways)/ np.mod()

# %%
rank_lst[list(['doc_1',np.dot()])]

# %%
np.dot()

# %%
array

# %%
print (q_new.values())

# %%
array = np.zeros(0,dtype=)

# %%
array

# %%
for i in range(len(q_vector)): 
    s = 0
    if q_vector[i] != 0:#in temp.keys():
        docs_tfidf = temp[q_vector[i]]
        
        print (temp[q_vector[i]])
        print('\n')

# %%
d1 = set([('doc1',2),('doc2',1)])

# %%
d2 = set(['doc1','doc3'])

# %%
docname = 'doc_7992'

# %%
len(docs)

# %%
r = list(filter(lambda x: x == docname,docs ))

# %%
q = [1,2,3]
ii2 = load_obj('inverted_index_TFIDF')
ii2 = {query:ii2[query] for query in q}

rank_lst = []
query_a = np.ones(len(array), dtype=float)

# filter the docs
docs = min(ii2.values())
for doc_id in docs:
    array = []
    for lst_value in ii2.values():
        array += (filter(lambda x:x[0]==doc_id, lst_value))

# %%
docs = min(ii2.values())

# %%
q = [1,2,3]
ii2 = load_obj('inverted_index_TFIDF')

new_dict = {query:ii2[query] for query in q}

rank_lst = []
query_a = np.ones(len(array), dtype=float)
docs = min(ii2.values())

for doc_id, _ in docs:
    array = []
    for lst_value in ii2.values():
        array += (filter(lambda x:x[0]==doc_id, lst_value))
    
    if len(array) == 3:
        array = np.array([x[1] for x in array])
        rank_lst.append(tuple([doc_id,round(1-cosine(array,ways),3)]))

# %%
q = [1,2,3]
ii2 = load_obj('inverted_index_TFIDF')

new_dict = {query:ii2[query] for query in q}

rank_lst = []
query_a = np.ones(len(array), dtype=float)
docs = min(ii2.values())

# %%
for docs_ID,_ in docs:
    print('ciao')
    break

# %%
docs

# %%
q = [1,2,3]
ii1 = load_obj('inverted_index_1')

ii1 = {query:ii1[query] for query in q}

rank_lst = []
query_a = np.ones(len(array), dtype=float)

docs = []

# %%
for i,lst in enumerate(ii1.values()):
    if i == 0:
        docs = set(lst)
    else:
        docs.intersection(lst)

# %%
ii2 = load_obj('inverted_index_TFIDF')
ii2 = {query:ii1[query] for query in q}

# %%
for doc_id in docs:
    array = []
    for lst_value in ii2.values():
        array += tuple(filter(lambda x:x[0]==doc_id, lst_value))
        
    if len(array) == len(ii2):
        array = np.array([x[1] for x in array])
        rank_lst.append(tuple([doc_id,round(1-cosine(array,ways),3)]))


if len(rank_lst) != 0:
    rank_lst.sort(key= lambda x:x[1], reverse=True )

# %%
a = [list(filter(lambda x: x[0] == 'doc1', [('doc1',1),('doc3',20)]))[0] for i in range(3)]

# %%
for doc_id in docs:
    array = []
    array += [list(filter(lambda x: x[0] == doc_id, lst_value))[0] for lst_value in ii2.values()]
  
    if len(array) == len(ii3):
        array = np.array([x[1] for x in array])
        rank_lst.append(tuple([doc_id,round(1-cosine(array,ways),3)]))


#if len(rank_lst) != 0:
#    rank_lst.sort(key= lambda x:x[1], reverse=True )

# %%
array
# Out:
# array([0, 1])

# %% [markdown]
# # prova

# %%
query = [1,2,3]

# %%
ii1 = load_obj('inverted_index_1')
ii1 = {query:ii1[query] for query in q}

# %%
#list(filter(lambda x: x[0] == 'doc_5153',prova))

# %%
#array += tuple(list(filter(lambda x: x[0] == 'doc_5153',prova)))

# %%
#array

# %%
vocabulary = load_obj('vocabulary')
vocabulary
# Out:
# {'2': 0,
#  'privat': 1,
#  'room': 2,
#  'bathroom': 3,
#  '10min': 4,
#  'iah': 5,
#  'airport': 6,
#  'welcom': 7,
#  'stay': 8,
#  'queen': 9,
#  'bed': 10,
#  'detach': 11,
#  'second': 12,
#  'floor': 13,
#  'anoth': 14,
#  'bedroom': 15,
#  'sofa': 16,
#  'avail': 17,
#  'addit': 18,
#  'guest': 19,
#  '10': 20,
#  'pick': 21,
#  'drop': 22,
#  'trip': 23,
#  'uniqu': 24,
#  'locat': 25,
#  'alamo': 26,
#  'height': 27,
#  'design': 28,
#  'inspir': 29,
#  'stylish': 30,
#  'fulli': 31,
#  'remodel': 32,
#  'home': 33,
#  'upscal': 34,
#  'NW': 35,
#  'area': 36,
#  'amaz': 37,
#  'hous': 38,
#  'conveni': 39,
#  'quiet': 40,
#  'street': 41,
#  'beauti': 42,
#  'season': 43,
#  'tree': 44,
#  'prestigi': 45,
#  'neighborhood': 46,
#  'close': 47,
#  '281': 48,
#  '410': 49,
#  'loop': 50,
#  'town': 51,
#  'featur': 52,
#  'open': 53,
#  'plan': 54,
#  'origin': 55,
#  'hardwood': 56,
#  '3': 57,
#  'full': 58,
#  'independ': 59,
#  'garden': 60,
#  'TV': 61,
#  'sleep': 62,
#  'european': 63,
#  'kitchen': 64,
#  'top': 65,
#  'line': 66,
#  'decor': 67,
#  'driveway': 68,
#  'park': 69,
#  '4': 70,
#  'car': 71,
#  'river': 72,
#  'near': 73,
#  'citi': 74,
#  'island': 75,
#  'well': 76,
#  'maintain': 77,
#  'san': 78,
#  'jacinto': 79,
#  'extra': 80,
#  'temporari': 81,
#  'visitor': 82,
#  'campu': 83,
#  'cute': 84,
#  'littl': 85,
#  'situat': 86,
#  'covet': 87,
#  'acr': 88,
#  'bryan': 89,
#  'access': 90,
#  'porch': 91,
#  '1920': 92,
#  'recent': 93,
#  'purchas': 94,
#  '1922': 95,
#  'mile': 96,
#  'outsid': 97,
#  'downtown': 98,
#  'fort': 99,
#  'worth': 100,
#  'happi': 101,
#  'restor': 102,
#  'charact': 103,
#  'built': 104,
#  '5': 105,
#  'minut': 106,
#  'drive': 107,
#  'offer': 108,
#  'across': 109,
#  'current': 110,
#  'rejuven': 111,
#  'gateway': 112,
#  'gorgeou': 113,
#  'countri': 114,
#  'set': 115,
#  'place': 116,
#  'lake': 117,
#  'conro': 118,
#  'famili': 119,
#  'friendli': 120,
#  'activ': 121,
#  'nightlif': 122,
#  'love': 123,
#  'outdoor': 124,
#  'space': 125,
#  'good': 126,
#  'coupl': 127,
#  'solo': 128,
#  'adventur': 129,
#  'busi': 130,
#  'travel': 131,
#  'kid': 132,
#  'big': 133,
#  'group': 134,
#  'cozi': 135,
#  'quaint': 136,
#  'retreat': 137,
#  'acreag': 138,
#  'rustic': 139,
#  '8': 140,
#  'southeast': 141,
#  'austin': 142,
#  'convert': 143,
#  'modular': 144,
#  'amen': 145,
#  'need': 146,
#  'texa': 147,
#  'experi': 148,
#  'less': 149,
#  '15': 150,
#  'circuit': 151,
#  'america': 152,
#  'cota': 153,
#  'formula': 154,
#  'one': 155,
#  'trailer': 156,
#  'َquiet': 157,
#  'size': 158,
#  'closet': 159,
#  'pet': 160,
#  'alway': 161,
#  'clean': 162,
#  'share': 163,
#  'suppli': 164,
#  'towel': 165,
#  'shampoo': 166,
#  'tcu': 167,
#  'tcc': 168,
#  'stockyard': 169,
#  '608': 170,
#  'bayfront': 171,
#  'condo': 172,
#  'first': 173,
#  'class': 174,
#  'comfort': 175,
#  'best': 176,
#  'view': 177,
#  'bottom': 178,
#  'deck': 179,
#  'master': 180,
#  'patio': 181,
#  'r': 182,
#  'pier': 183,
#  'step': 184,
#  'away': 185,
#  'histor': 186,
#  'studio': 187,
#  'entranc': 188,
#  '1': 189,
#  'pool': 190,
#  'cool': 191,
#  'apart': 192,
#  'feel': 193,
#  'like': 194,
#  'fit': 195,
#  'peopl': 196,
#  'central': 197,
#  'enjoy': 198,
#  'gourmet': 199,
#  'easi': 200,
#  'major': 201,
#  'highway': 202,
#  'gate': 203,
#  'estat': 204,
#  'heart': 205,
#  'dfw': 206,
#  'metro': 207,
#  'wood': 208,
#  'overlook': 209,
#  'pond': 210,
#  'min': 211,
#  '25': 212,
#  '35': 213,
#  'field': 214,
#  'dalla': 215,
#  'amp': 216,
#  'american': 217,
#  'airlin': 218,
#  'center': 219,
#  'museum': 220,
#  'deep': 221,
#  'elum': 222,
#  'stadium': 223,
#  'global': 224,
#  'life': 225,
#  'six': 226,
#  'flag': 227,
#  'stock': 228,
#  'yard': 229,
#  'motor': 230,
#  'speed': 231,
#  'way': 232,
#  'grapevin': 233,
#  'mill': 234,
#  'mall': 235,
#  'gaylord': 236,
#  'texan': 237,
#  'great': 238,
#  'wolf': 239,
#  'lodg': 240,
#  'check': 241,
#  'list': 242,
#  'fabeuless': 243,
#  'hideaway': 244,
#  'cypress': 245,
#  'creek': 246,
#  'hamilton': 247,
#  'combin': 248,
#  'visit': 249,
#  'also': 250,
#  'far': 251,
#  'madden': 252,
#  'crowd': 253,
#  'peac': 254,
#  'die': 255,
#  'natur': 256,
#  'spade': 257,
#  'hum': 258,
#  'bird': 259,
#  'galor': 260,
#  'come': 261,
#  'see': 262,
#  'north': 263,
#  'side': 264,
#  'antonio': 265,
#  'golf': 266,
#  'cours': 267,
#  'JW': 268,
#  'marriott': 269,
#  'resort': 270,
#  'spa': 271,
#  'stop': 272,
#  'cabl': 273,
#  'internet': 274,
#  'laundri': 275,
#  'green': 276,
#  'belt': 277,
#  'back': 278,
#  'safe': 279,
#  'neighbor': 280,
#  'hope': 281,
#  'cottag': 282,
#  'charm': 283,
#  'right': 284,
#  'kerrvil': 285,
#  'pine': 286,
#  'ceil': 287,
#  'fireplac': 288,
#  'appeal': 289,
#  'eclect': 290,
#  'screen': 291,
#  'huge': 292,
#  'backyard': 293,
#  'washer': 294,
#  'dryer': 295,
#  'use': 296,
#  'base': 297,
#  'explor': 298,
#  'wine': 299,
#  'nearbi': 300,
#  'cover': 301,
#  'carport': 302,
#  'includ': 303,
#  'rental': 304,
#  'price': 305,
#  'get': 306,
#  'rain': 307,
#  'bad': 308,
#  'weather': 309,
#  'protext': 310,
#  'bath': 311,
#  'new': 312,
#  'hint': 313,
#  'chic': 314,
#  'cosi': 315,
#  'hyde': 316,
#  'two': 317,
#  'lot': 318,
#  'window': 319,
#  'sunni': 320,
#  'front': 321,
#  'UT': 322,
#  'walk': 323,
#  'coffe': 324,
#  'shop': 325,
#  'restaur': 326,
#  'ocean': 327,
#  'getaway': 328,
#  'magnific': 329,
#  'beach': 330,
#  'dine': 331,
#  'super': 332,
#  'bowl': 333,
#  '2017': 334,
#  'bdrm': 335,
#  'entertain': 336,
#  '59': 337,
#  'beltway': 338,
#  'lewisvil': 339,
#  'lakefront': 340,
#  'frisco': 341,
#  'perfect': 342,
#  'creat': 343,
#  'wonder': 344,
#  'memori': 345,
#  'friend': 346,
#  'yet': 347,
#  'relax': 348,
#  'atmospher': 349,
#  'luxuri': 350,
#  '12': 351,
#  'theater': 352,
#  'plu': 353,
#  'castleg': 354,
#  'nice': 355,
#  '50': 356,
#  'inch': 357,
#  'flat': 358,
#  'live': 359,
#  'main': 360,
#  'ampl': 361,
#  'host': 362,
#  'ping': 363,
#  'pong': 364,
#  'tabl': 365,
#  'garag': 366,
#  'request': 367,
#  'time': 368,
#  'everyon': 369,
#  'workout': 370,
#  'equip': 371,
#  'leisur': 372,
#  'vehicl': 373,
#  'quit': 374,
#  'neibourhood': 375,
#  'kati': 376,
#  'lacentera': 377,
#  'movi': 378,
#  'grand': 379,
#  'parkway': 380,
#  'comfi': 381,
#  'light': 382,
#  'carriag': 383,
#  'distanc': 384,
#  'denton': 385,
#  'univers': 386,
#  'dcta': 387,
#  'bu': 388,
#  'train': 389,
#  'station': 390,
#  'kitchenett': 391,
#  'microwav': 392,
#  'refriger': 393,
#  'freezer': 394,
#  'pot': 395,
#  'murphi': 396,
#  'downstair': 397,
#  'loft': 398,
#  'air': 399,
#  'mattress': 400,
#  'pleas': 401,
#  'caution': 402,
#  'ladder': 403,
#  'stair': 404,
#  'chaletazul': 405,
#  '2rm': 406,
#  '4bd': 407,
#  '30day': 408,
#  'rent': 409,
#  'chalet': 410,
#  '6': 411,
#  'hottub': 412,
#  '18': 413,
#  '20': 414,
#  'sea': 415,
#  'world': 416,
#  'fiesta': 417,
#  'gruen': 418,
#  'braunfel': 419,
#  'onsit': 420,
#  'concierg': 421,
#  'medicin': 422,
#  'massag': 423,
#  'babysit': 424,
#  'discount': 425,
#  'king': 426,
#  'warm': 427,
#  'vacat': 428,
#  'extend': 429,
#  'childbirth': 430,
#  'tourist': 431,
#  'special': 432,
#  'talk': 433,
#  'spanish': 434,
#  'english': 435,
#  'french': 436,
#  'fabul': 437,
#  'tradit': 438,
#  'interior': 439,
#  'furnitur': 440,
#  'soco': 441,
#  'acl': 442,
#  'sxsw': 443,
#  'sola': 444,
#  'eateri': 445,
#  'bar': 446,
#  'larg': 447,
#  'doubl': 448,
#  'accommod': 449,
#  'free': 450,
#  'wifi': 451,
#  'reserv': 452,
#  'TH': 453,
#  'upstair': 454,
#  'commun': 455,
#  'seriou': 456,
#  'inquiri': 457,
#  'renov': 458,
#  'plano': 459,
#  'school': 460,
#  'around': 461,
#  'mind': 462,
#  'prepar': 463,
#  'everyth': 464,
#  'brand': 465,
#  'find': 466,
#  'hotel': 467,
#  'provid': 468,
#  'much': 469,
#  'high': 470,
#  'ultim': 471,
#  'fast': 472,
#  '200': 473,
#  'mbp': 474,
#  '55': 475,
#  'smart': 476,
#  'netflix': 477,
#  'local': 478,
#  'channel': 479,
#  'grill': 480,
#  'studi': 481,
#  'etc': 482,
#  'book': 483,
#  'couch': 484,
#  'surf': 485,
#  'rail': 486,
#  'goe': 487,
#  'apt': 488,
#  'fun': 489,
#  'five': 490,
#  'seven': 491,
#  'directli': 492,
#  'ballpark': 493,
#  'arlington': 494,
#  'hurrican': 495,
#  'harbor': 496,
#  'treed': 497,
#  'trail': 498,
#  'attract': 499,
#  'entir': 500,
#  '400': 501,
#  'sq': 502,
#  'ft': 503,
#  'attach': 504,
#  'desir': 505,
#  'tarrytown': 506,
#  '1940': 507,
#  'licens': 508,
#  'oper': 509,
#  'short': 510,
#  'term': 511,
#  'note': 512,
#  'occup': 513,
#  'tax': 514,
#  'star': 515,
#  'night': 516,
#  'bedrol': 517,
#  'bunkhous': 518,
#  'ranch': 519,
#  'nestl': 520,
#  '30': 521,
#  'landscap': 522,
#  'hors': 523,
#  'shoe': 524,
#  'pit': 525,
#  'gazz': 526,
#  'listen': 527,
#  'coyot': 528,
#  'sing': 529,
#  'sit': 530,
#  'read': 531,
#  'monro': 532,
#  'manor': 533,
#  'water': 534,
#  'style': 535,
#  'shiplap': 536,
#  'wall': 537,
#  'even': 538,
#  'better': 539,
#  'amethyst': 540,
#  'canyon': 541,
#  'venu': 542,
#  'poodi': 543,
#  'roadhous': 544,
#  'pace': 545,
#  'bend': 546,
#  'pedernal': 547,
#  'marbl': 548,
#  'fall': 549,
#  'hill': 550,
#  'api': 551,
#  'hike': 552,
#  'play': 553,
#  'launch': 554,
#  'boat': 555,
#  'ambianc': 556,
#  'dog': 557,
#  'cat': 558,
#  'properti': 559,
#  '1953': 560,
#  'spartanett': 561,
#  'guesthous': 562,
#  'modern': 563,
#  'spartan': 564,
#  'shade': 565,
#  'casa': 566,
#  'de': 567,
#  'alexi': 568,
#  'guesthom': 569,
#  'laid': 570,
#  'plenti': 571,
#  'caretak': 572,
#  'excel': 573,
#  'safeti': 574,
#  'goal': 575,
#  'wheel': 576,
#  'chair': 577,
#  'handicap': 578,
#  'shower': 579,
#  'w': 580,
#  'key': 581,
#  'low': 582,
#  'cost': 583,
#  'motel': 584,
#  'door': 585,
#  'lock': 586,
#  'schedul': 587,
#  'arriv': 588,
#  'may': 589,
#  'greet': 590,
#  'anytim': 591,
#  '1pm': 592,
#  'day': 593,
#  '24': 594,
#  '7': 595,
#  'keyless': 596,
#  'entri': 597,
#  'code': 598,
#  'info': 599,
#  'know': 600,
#  'detail': 601,
#  'email': 602,
#  'airbnb': 603,
#  'confirm': 604,
#  '100': 605,
#  'hassl': 606,
#  'bicker': 607,
#  'ST': 608,
#  'N': 609,
#  'westmoreland': 610,
#  'RD': 611,
#  '75212': 612,
#  'femal': 613,
#  'comal': 614,
#  'schlitterbahn': 615,
#  'hideway': 616,
#  'furnish': 617,
#  'unit': 618,
#  'take': 619,
#  'advantag': 620,
#  'along': 621,
#  'insid': 622,
#  'spectacular': 623,
#  'make': 624,
#  'next': 625,
#  'rememb': 626,
#  'eleg': 627,
#  'rest': 628,
#  '4k': 629,
#  'bigger': 630,
#  'fire': 631,
#  'complet': 632,
#  'readi': 633,
#  'brick': 634,
#  'per': 635,
#  'direct': 636,
#  '500': 637,
#  'watch': 638,
#  'sheet': 639,
#  'pillow': 640,
#  'case': 641,
#  'summon': 642,
#  'sanctuari': 643,
#  'abilen': 644,
#  'stylishli': 645,
#  'updat': 646,
#  'taylor': 647,
#  'counti': 648,
#  'expo': 649,
#  'shotwel': 650,
#  'zoo': 651,
#  'lyle': 652,
#  'land': 653,
#  'cattl': 654,
#  'finish': 655,
#  'standard': 656,
#  'valu': 657,
#  'prestig': 658,
#  'move': 659,
#  'bungalow': 660,
#  'craftsman': 661,
#  'ride': 662,
#  'bikeshar': 663,
#  'samuel': 664,
#  'ave': 665,
#  'connect': 666,
#  'point': 667,
#  'west': 668,
#  '7th': 669,
#  'district': 670,
#  'magnolia': 671,
#  'triniti': 672,
#  'track': 673,
#  'ambient': 674,
#  'nois': 675,
#  'ad': 676,
#  'year': 677,
#  'concept': 678,
#  'TX': 679,
#  'sleeper': 680,
#  'maximum': 681,
#  'descript': 682,
#  'singl': 683,
#  'pasadena': 684,
#  '21': 685,
#  'nrg': 686,
#  'allow': 687,
#  'suit': 688,
#  'june': 689,
#  'juli': 690,
#  'kyle': 691,
#  'georg': 692,
#  'bush': 693,
#  'librari': 694,
#  'northgat': 695,
#  'eat': 696,
#  'tidi': 697,
#  'mani': 698,
#  'reason': 699,
#  'person': 700,
#  'morn': 701,
#  'Br': 702,
#  'Ba': 703,
#  'orient': 704,
#  '75': 705,
#  '121': 706,
#  '45': 707,
#  'rang': 708,
#  'within': 709,
#  'premium': 710,
#  'outlet': 711,
#  'stonebriar': 712,
#  'watter': 713,
#  'parti': 714,
#  'hackberri': 715,
#  'total': 716,
#  'twin': 717,
#  'futon': 718,
#  'electr': 719,
#  'stove': 720,
#  'refrigeratior': 721,
#  'icemak': 722,
#  'toaster': 723,
#  'coffeepot': 724,
#  'utensil': 725,
#  'plate': 726,
#  'cookwar': 727,
#  'linen': 728,
#  'dish': 729,
#  'AC': 730,
#  'heat': 731,
#  'bandera': 732,
#  'smoke': 733,
#  'ferral': 734,
#  'fed': 735,
#  '2016': 736,
#  'stori': 737,
#  '2br': 738,
#  '70': 739,
#  'tv': 740,
#  'inflat': 741,
#  'groceri': 742,
#  'store': 743,
#  'hr': 744,
#  'emerg': 745,
#  'gym': 746,
#  'treadmil': 747,
#  'erg': 748,
#  'machin': 749,
#  'crate': 750,
#  'german': 751,
#  'shepherd': 752,
#  'limit': 753,
#  '1st': 754,
#  'convent': 755,
#  'hemisfair': 756,
#  'alamodom': 757,
#  'southtown': 758,
#  'array': 759,
#  'public': 760,
#  'basebal': 761,
#  'playground': 762,
#  'picnic': 763,
#  'intern': 764,
#  'bike': 765,
#  'rack': 766,
#  'block': 767,
#  'hwi': 768,
#  '69': 769,
#  'third': 770,
#  'offic': 771,
#  'work': 772,
#  'RV': 773,
#  'US': 774,
#  'NE': 775,
#  'medic': 776,
#  'kingwood': 777,
#  'monday': 778,
#  'thursday': 779,
#  'often': 780,
#  'except': 781,
#  'environ': 782,
#  'allianc': 783,
#  'i35': 784,
#  'look': 785,
#  'long': 786,
#  'student': 787,
#  'profession': 788,
#  'renter': 789,
#  '3br': 790,
#  '2B': 791,
#  'fantast': 792,
#  'bienvenido': 793,
#  'tailor': 794,
#  'proxim': 795,
#  'houston': 796,
#  'typhoon': 797,
#  'energi': 798,
#  'corridor': 799,
#  'hospit': 800,
#  'sincer': 801,
#  'profit': 802,
#  'dear': 803,
#  'la': 804,
#  'colina': 805,
#  'newli': 806,
#  'lit': 807,
#  'tub': 808,
#  'accompani': 809,
#  'surround': 810,
#  'background': 811,
#  'complimentari': 812,
#  '2min': 813,
#  'clara': 814,
#  'martin': 815,
#  'sunset': 816,
#  'clear': 817,
#  'everi': 818,
#  'bring': 819,
#  'kayak': 820,
#  'jet': 821,
#  'ski': 822,
#  '40': 823,
#  'slip': 824,
#  'afford': 825,
#  'med': 826,
#  'spare': 827,
#  'hermann': 828,
#  'rice': 829,
#  'nearest': 830,
#  'toiletri': 831,
#  'culdasec': 832,
#  'colleg': 833,
#  'borderlin': 834,
#  'boast': 835,
#  'spaciou': 836,
#  'tile': 837,
#  'counter': 838,
#  'breakfast': 839,
#  'enough': 840,
#  'quick': 841,
#  'either': 842,
#  'tanglewood': 843,
#  'splashpad': 844,
#  'effect': 845,
#  'basic': 846,
#  'applianc': 847,
#  'silverwar': 848,
#  'cook': 849,
#  'ware': 850,
#  'glass': 851,
#  'unwind': 852,
#  'ton': 853,
#  'poolsid': 854,
#  'regist': 855,
#  'saltwat': 856,
#  'jacuzzi': 857,
#  'pm': 858,
#  'start': 859,
#  'jog': 860,
#  'game': 861,
#  'tenni': 862,
#  'basketbal': 863,
#  'fill': 864,
#  'healthi': 865,
#  'lifestyl': 866,
#  'blanco': 867,
#  'concan': 868,
#  'hole': 869,
#  'highest': 870,
#  '4342': 871,
#  'livabl': 872,
#  '28': 873,
#  'level': 874,
#  '635': 875,
#  'garland': 876,
#  'mesquit': 877,
#  'pictur': 878,
#  'hanger': 879,
#  'chiffarob': 880,
#  'shelv': 881,
#  'chest': 882,
#  'drawer': 883,
#  '60': 884,
#  'treehous': 885,
#  'oasi': 886,
#  'actual': 887,
#  '2nd': 888,
#  'lamin': 889,
#  'perk': 890,
#  'self': 891,
#  'trundl': 892,
#  'traffic': 893,
#  'establish': 894,
#  'IH': 895,
#  'bamc': 896,
#  'uthscsa': 897,
#  'anyon': 898,
#  'emerald': 899,
#  'gem': 900,
#  'among': 901,
#  'old': 902,
#  'growth': 903,
#  'oak': 904,
#  'potter': 905,
#  'weekend': 906,
#  'spot': 907,
#  'decompress': 908,
#  'import': 909,
#  'scent': 910,
#  'cedar': 911,
#  'reinvigor': 912,
#  'crystal': 913,
#  'call': 914,
#  'name': 915,
#  'strateg': 916,
#  'hour': 917,
#  'wimberley': 918,
#  'fredericksburg': 919,
#  'word': 920,
#  'CC': 921,
#  'shadow': 922,
#  'glen': 923,
#  'week': 924,
#  'longer': 925,
#  'other': 926,
#  'beverag': 927,
#  'fellowship': 928,
#  'condominium': 929,
#  'might': 930,
#  'victorian': 931,
#  'farmhous': 932,
#  'delight': 933,
#  'ensuit': 934,
#  'pc': 935,
#  'keurig': 936,
#  'roll': 937,
#  'squar': 938,
#  'mckinney': 939,
#  'known': 940,
#  'vibrant': 941,
#  'testament': 942,
#  'money': 943,
#  'magazin': 944,
#  'rate': 945,
#  '2bdr': 946,
#  '2bath': 947,
#  'woodland': 948,
#  '12hp02': 949,
#  'execut': 950,
#  '1200': 951,
#  'anybodi': 952,
#  'would': 953,
#  'delici': 954,
#  'meal': 955,
#  'dramat': 956,
#  'nine': 957,
#  'foot': 958,
#  'ceram': 959,
#  'custom': 960,
#  'trim': 961,
#  'crown': 962,
#  'mold': 963,
#  'fan': 964,
#  'comput': 965,
#  'desk': 966,
#  'overs': 967,
#  'expans': 968,
#  'gameday': 969,
#  'sleepov': 970,
#  'tamu': 971,
#  'superbowl': 972,
#  'multipl': 973,
#  'hobbi': 974,
#  'walmart': 975,
#  'furri': 976,
#  'semi': 977,
#  'meadow': 978,
#  'euless': 979,
#  'Ft': 980,
#  'cowboy': 981,
#  'ranger': 982,
#  'charg': 983,
#  'fee': 984,
#  'burnet': 985,
#  'brentwood': 986,
#  'found': 987,
#  'pad': 988,
#  'stone': 989,
#  'throw': 990,
#  'transit': 991,
#  'sever': 992,
#  'lala': 993,
#  'famou': 994,
#  'christma': 995,
#  'pour': 996,
#  'aristocrat': 997,
#  'notch': 998,
#  'stubb': 999,
#  ...}

# %% [markdown]
# # prova

# %%
q = [1,2,3]
ii1 = load_obj('inverted_index_1')
ii1 = {query:ii1[query] for query in q}

rank_lst = []

# %%
docs = []
for i,value_lst in enumerate(ii1.values()):
    if i == 0:
        docs = set(value_lst)
    else:
        docs.intersection(set(value_lst))

# %%
# find the smallest list values in dictionary:

smallest_value = []
docs = []
for i,key in enumerate(ii1.keys()):
    if i == 0:
        smallest_value = ii1[key]
        smallest_key = key
    else:
        if len(smallest_value) > len(ii1[key]):
            smallest_value = ii1[key]
            smallest_key = key

docs = set(ii1[smallest_key])

for key in ii1.keys():
    docs.intersection(ii1[key])

# %%
smallest_value = []
docs = []
for i,key in enumerate(ii1.keys()):
    if i == 0:
        smallest_value = ii1[key]
        smallest_key = key
    else:
        if len(smallest_value) > len(ii1[key]):
            smallest_value = ii1[key]
            smallest_key = key

docs = set(ii1[smallest_key])

for key in ii1.keys():
    docs.intersection(ii1[key])

# %%
docs = []
for i,key in enumerate(ii1.keys()):
    if i == 0:
        docs = set(ii1[key])
    else:
        docs.intersection(set(ii1[key]))

# %%
query = set([1,2,3])
docs = []
ii1 = load_obj('inverted_index_1')
ii1 = {query:ii1[query] for query in q}
docs = set.intersection(*[set(value) for value in ii1.values()])

# %%
len(docs)
# Out:
# 1066

# %%
ii2 = load_obj('inverted_index_TFIDF')
ii2 = {query:ii2[query] for query in q}
query_array = np.ones(len(query), dtype=float)

# %%
rank_lst = []

# %%
for doc_id in docs:
    array = []
    for lst_value in ii2.values():
        array += tuple(filter(lambda x:x[0]==doc_id, lst_value))
        
    #if len(array) == len(ii2):
    array = np.array([x[1] for x in array])
    rank_lst.append(tuple([doc_id,(1-cosine(array,query_array))]))

rank_lst.sort(key = lambda x: x[1],reverse=True)

# %%
#rank_lst
from time import time

# %% [markdown]
# # point 3.2

# %%
from time import time

# %%
start = time()
query = 'room with private bathroom'
query = remove_step(query).split(' ')
vocabulary = load_obj('vocabulary')
query = filter(lambda x: x in vocabulary.keys(),query)
query = list(map(lambda x: vocabulary[x], query))


docs = []
ii1 = load_obj('inverted_index_1')
ii1 = {term_id:ii1[term_id] for term_id in query}
docs = set.intersection(*[set(value) for value in ii1.values()])

ii2 = load_obj('inverted_index_TFIDF')
ii2 = {term_id:ii2[term_id] for term_id in query}
query_array = np.ones(len(query), dtype=float)


rank_lst = []

for doc_id in docs:
    array = []
    for lst_value in ii2.values():
        array += tuple(filter(lambda x:x[0]==doc_id, lst_value))
        
    #if len(array) == len(ii2):
    array = np.array([x[1] for x in array])
    rank_lst.append(tuple([doc_id,(1-cosine(array,query_array))]))

rank_lst.sort(key = lambda x: x[1],reverse=True)
print(time()-start)
# Out:
# 2.996943235397339

# %%
# BETTER ONE

# %%
def search_engine_2(query):

    query = remove_step(query).split(' ')
    vocabulary = load_obj('vocabulary')
    query = filter(lambda x: x in vocabulary.keys(),query)
    query = list(map(lambda x: vocabulary[x], query))


    docs = []
    ii1 = load_obj('inverted_index_1')
    ii1 = {term_id:ii1[term_id] for term_id in query}
    docs = set.intersection(*[set(value) for value in ii1.values()])

    ii2 = load_obj('inverted_index_TFIDF')
    ii2 = {term_id:ii2[term_id] for term_id in query}
    query_array = np.ones(len(query), dtype=float)


    rank_lst = []

    for doc_id in docs:
        array = []
        for item in query:
            array += tuple(filter(lambda x:x[0]==doc_id, ii2[item]))

        #if len(array) == len(ii2):
        array = np.array([x[1] for x in array])
        rank_lst.append(tuple([doc_id,(1-cosine(array,query_array))]))

    rank_lst.sort(key = lambda x: x[1], reverse = True)
    
    df = first_k_documents(rank_lst, 5)
    return df

# %%
def first_k_documents(rank_lst, k = 5):
    
    list_for_df = []
    for i in range(k):
        with open ("data/docs/" + rank_lst[i][0] + '.tsv') as doc:
            row = doc.read()
            lst = row.split('\t')
            lst = [lst[7],lst[4],lst[2],lst[8], round(rank_lst[i][1],3)]
            list_for_df.append(lst)

    return pd.DataFrame(list_for_df, columns=['Title', 'Description', 'City', 'Url', 'Similarity'])

# %%
start = time()
df = search_engine_2('room with private bathroom')
print(time()-start)
df
# Out:
# 2.627304792404175
#                                                Title  \
# 0  Big room w/ private entrance and private bathroom
# 1     Pool/Hot Tub - 3 Room Suite - Private Bathroom
# 2  Spacious Bedroom w/ Private Entrance and Bathroom
# 3     Pool/Hot Tub - 3 Room Suite - Private Bathroom
# 4  Big room w/ private entrance and private bathroom
#
#                                          Description    City  \
# 0  Enjoy a private room with your own dedicated e...  Denton
# 1  Two bedrooms, a sitting room &amp; a private b...  DeSoto
# 2  Spacious room with a private entrance and priv...  Austin
# 3  Two bedrooms, a sitting room &amp; a private b...  DeSoto
# 4  Enjoy a private room with your own dedicated e...  Denton
#
#                                                  Url  Similarity
# 0  https://www.airbnb.com/rooms/14450478?location...       0.999
# 1  https://www.airbnb.com/rooms/12791862?location...       0.999
# 2  https://www.airbnb.com/rooms/17365892?location...       0.999
# 3  https://www.airbnb.com/rooms/12791862?location...       0.999
# 4  https://www.airbnb.com/rooms/14450478?location...       0.999

# %%
first_k_documents(rank_lst, 5)
# Out:
#                                                Title  \
# 0  Big room w/ private entrance and private bathroom
# 1  Big room w/ private entrance and private bathroom
# 2             North Austin private room and bathroom
# 3     Pool/Hot Tub - 3 Room Suite - Private Bathroom
# 4  Big room w/ private entrance and private bathroom
#
#                                          Description    City  \
# 0  Enjoy a private room with your own dedicated e...  Denton
# 1  Enjoy a private room with your own dedicated e...  Denton
# 2  Private room in a second-floor flat of a two-y...  Austin
# 3  Two bedrooms, a sitting room &amp; a private b...  DeSoto
# 4  Enjoy a private room with your own dedicated e...  Denton
#
#                                                  Url  Similarity
# 0  https://www.airbnb.com/rooms/14450478?location...       0.999
# 1  https://www.airbnb.com/rooms/14450478?location...       0.999
# 2  https://www.airbnb.com/rooms/17463665?location...       0.999
# 3  https://www.airbnb.com/rooms/12791862?location...       0.999
# 4  https://www.airbnb.com/rooms/14450478?location...       0.999

# %%
for i in range(10):
    print(rank_lst[i][0])
# Out:
# doc_15988
# doc_16309
# doc_7508
# doc_544
# doc_2470
# doc_8424
# doc_7859
# doc_13970
# doc_12679
# doc_4869

# %%
('doc_8424', 0.9993531235127938)
('doc_16309', 0.9993531235127938)
('doc_15988', 0.9993531235127938)
('doc_7859', 0.9993531235127938)
('doc_544', 0.9993531235127938)
('doc_7508', 0.9993531235127938)
('doc_2470', 0.9993531235127938)
('doc_4869', 0.9894524449320425)
('doc_3374', 0.9894524449320425)
('doc_8859', 0.9894524449320425)

# %%
queryarray = np.array([2,1,3])

# %%
array = np.array([14,10,2,0])
array = np.take(array, [2,1,3])
array = np.nonzero(array)[0]

# %%
array
# Out:
# array([0, 1])

# %%
vocabulary
# Out:
# {'2': 0,
#  'privat': 1,
#  'room': 2,
#  'bathroom': 3,
#  '10min': 4,
#  'iah': 5,
#  'airport': 6,
#  'welcom': 7,
#  'stay': 8,
#  'queen': 9,
#  'bed': 10,
#  'detach': 11,
#  'second': 12,
#  'floor': 13,
#  'anoth': 14,
#  'bedroom': 15,
#  'sofa': 16,
#  'avail': 17,
#  'addit': 18,
#  'guest': 19,
#  '10': 20,
#  'pick': 21,
#  'drop': 22,
#  'trip': 23,
#  'uniqu': 24,
#  'locat': 25,
#  'alamo': 26,
#  'height': 27,
#  'design': 28,
#  'inspir': 29,
#  'stylish': 30,
#  'fulli': 31,
#  'remodel': 32,
#  'home': 33,
#  'upscal': 34,
#  'NW': 35,
#  'area': 36,
#  'amaz': 37,
#  'hous': 38,
#  'conveni': 39,
#  'quiet': 40,
#  'street': 41,
#  'beauti': 42,
#  'season': 43,
#  'tree': 44,
#  'prestigi': 45,
#  'neighborhood': 46,
#  'close': 47,
#  '281': 48,
#  '410': 49,
#  'loop': 50,
#  'town': 51,
#  'featur': 52,
#  'open': 53,
#  'plan': 54,
#  'origin': 55,
#  'hardwood': 56,
#  '3': 57,
#  'full': 58,
#  'independ': 59,
#  'garden': 60,
#  'TV': 61,
#  'sleep': 62,
#  'european': 63,
#  'kitchen': 64,
#  'top': 65,
#  'line': 66,
#  'decor': 67,
#  'driveway': 68,
#  'park': 69,
#  '4': 70,
#  'car': 71,
#  'river': 72,
#  'near': 73,
#  'citi': 74,
#  'island': 75,
#  'well': 76,
#  'maintain': 77,
#  'san': 78,
#  'jacinto': 79,
#  'extra': 80,
#  'temporari': 81,
#  'visitor': 82,
#  'campu': 83,
#  'cute': 84,
#  'littl': 85,
#  'situat': 86,
#  'covet': 87,
#  'acr': 88,
#  'bryan': 89,
#  'access': 90,
#  'porch': 91,
#  '1920': 92,
#  'recent': 93,
#  'purchas': 94,
#  '1922': 95,
#  'mile': 96,
#  'outsid': 97,
#  'downtown': 98,
#  'fort': 99,
#  'worth': 100,
#  'happi': 101,
#  'restor': 102,
#  'charact': 103,
#  'built': 104,
#  '5': 105,
#  'minut': 106,
#  'drive': 107,
#  'offer': 108,
#  'across': 109,
#  'current': 110,
#  'rejuven': 111,
#  'gateway': 112,
#  'gorgeou': 113,
#  'countri': 114,
#  'set': 115,
#  'place': 116,
#  'lake': 117,
#  'conro': 118,
#  'famili': 119,
#  'friendli': 120,
#  'activ': 121,
#  'nightlif': 122,
#  'love': 123,
#  'outdoor': 124,
#  'space': 125,
#  'good': 126,
#  'coupl': 127,
#  'solo': 128,
#  'adventur': 129,
#  'busi': 130,
#  'travel': 131,
#  'kid': 132,
#  'big': 133,
#  'group': 134,
#  'cozi': 135,
#  'quaint': 136,
#  'retreat': 137,
#  'acreag': 138,
#  'rustic': 139,
#  '8': 140,
#  'southeast': 141,
#  'austin': 142,
#  'convert': 143,
#  'modular': 144,
#  'amen': 145,
#  'need': 146,
#  'texa': 147,
#  'experi': 148,
#  'less': 149,
#  '15': 150,
#  'circuit': 151,
#  'america': 152,
#  'cota': 153,
#  'formula': 154,
#  'one': 155,
#  'trailer': 156,
#  'َquiet': 157,
#  'size': 158,
#  'closet': 159,
#  'pet': 160,
#  'alway': 161,
#  'clean': 162,
#  'share': 163,
#  'suppli': 164,
#  'towel': 165,
#  'shampoo': 166,
#  'tcu': 167,
#  'tcc': 168,
#  'stockyard': 169,
#  '608': 170,
#  'bayfront': 171,
#  'condo': 172,
#  'first': 173,
#  'class': 174,
#  'comfort': 175,
#  'best': 176,
#  'view': 177,
#  'bottom': 178,
#  'deck': 179,
#  'master': 180,
#  'patio': 181,
#  'r': 182,
#  'pier': 183,
#  'step': 184,
#  'away': 185,
#  'histor': 186,
#  'studio': 187,
#  'entranc': 188,
#  '1': 189,
#  'pool': 190,
#  'cool': 191,
#  'apart': 192,
#  'feel': 193,
#  'like': 194,
#  'fit': 195,
#  'peopl': 196,
#  'central': 197,
#  'enjoy': 198,
#  'gourmet': 199,
#  'easi': 200,
#  'major': 201,
#  'highway': 202,
#  'gate': 203,
#  'estat': 204,
#  'heart': 205,
#  'dfw': 206,
#  'metro': 207,
#  'wood': 208,
#  'overlook': 209,
#  'pond': 210,
#  'min': 211,
#  '25': 212,
#  '35': 213,
#  'field': 214,
#  'dalla': 215,
#  'amp': 216,
#  'american': 217,
#  'airlin': 218,
#  'center': 219,
#  'museum': 220,
#  'deep': 221,
#  'elum': 222,
#  'stadium': 223,
#  'global': 224,
#  'life': 225,
#  'six': 226,
#  'flag': 227,
#  'stock': 228,
#  'yard': 229,
#  'motor': 230,
#  'speed': 231,
#  'way': 232,
#  'grapevin': 233,
#  'mill': 234,
#  'mall': 235,
#  'gaylord': 236,
#  'texan': 237,
#  'great': 238,
#  'wolf': 239,
#  'lodg': 240,
#  'check': 241,
#  'list': 242,
#  'fabeuless': 243,
#  'hideaway': 244,
#  'cypress': 245,
#  'creek': 246,
#  'hamilton': 247,
#  'combin': 248,
#  'visit': 249,
#  'also': 250,
#  'far': 251,
#  'madden': 252,
#  'crowd': 253,
#  'peac': 254,
#  'die': 255,
#  'natur': 256,
#  'spade': 257,
#  'hum': 258,
#  'bird': 259,
#  'galor': 260,
#  'come': 261,
#  'see': 262,
#  'north': 263,
#  'side': 264,
#  'antonio': 265,
#  'golf': 266,
#  'cours': 267,
#  'JW': 268,
#  'marriott': 269,
#  'resort': 270,
#  'spa': 271,
#  'stop': 272,
#  'cabl': 273,
#  'internet': 274,
#  'laundri': 275,
#  'green': 276,
#  'belt': 277,
#  'back': 278,
#  'safe': 279,
#  'neighbor': 280,
#  'hope': 281,
#  'cottag': 282,
#  'charm': 283,
#  'right': 284,
#  'kerrvil': 285,
#  'pine': 286,
#  'ceil': 287,
#  'fireplac': 288,
#  'appeal': 289,
#  'eclect': 290,
#  'screen': 291,
#  'huge': 292,
#  'backyard': 293,
#  'washer': 294,
#  'dryer': 295,
#  'use': 296,
#  'base': 297,
#  'explor': 298,
#  'wine': 299,
#  'nearbi': 300,
#  'cover': 301,
#  'carport': 302,
#  'includ': 303,
#  'rental': 304,
#  'price': 305,
#  'get': 306,
#  'rain': 307,
#  'bad': 308,
#  'weather': 309,
#  'protext': 310,
#  'bath': 311,
#  'new': 312,
#  'hint': 313,
#  'chic': 314,
#  'cosi': 315,
#  'hyde': 316,
#  'two': 317,
#  'lot': 318,
#  'window': 319,
#  'sunni': 320,
#  'front': 321,
#  'UT': 322,
#  'walk': 323,
#  'coffe': 324,
#  'shop': 325,
#  'restaur': 326,
#  'ocean': 327,
#  'getaway': 328,
#  'magnific': 329,
#  'beach': 330,
#  'dine': 331,
#  'super': 332,
#  'bowl': 333,
#  '2017': 334,
#  'bdrm': 335,
#  'entertain': 336,
#  '59': 337,
#  'beltway': 338,
#  'lewisvil': 339,
#  'lakefront': 340,
#  'frisco': 341,
#  'perfect': 342,
#  'creat': 343,
#  'wonder': 344,
#  'memori': 345,
#  'friend': 346,
#  'yet': 347,
#  'relax': 348,
#  'atmospher': 349,
#  'luxuri': 350,
#  '12': 351,
#  'theater': 352,
#  'plu': 353,
#  'castleg': 354,
#  'nice': 355,
#  '50': 356,
#  'inch': 357,
#  'flat': 358,
#  'live': 359,
#  'main': 360,
#  'ampl': 361,
#  'host': 362,
#  'ping': 363,
#  'pong': 364,
#  'tabl': 365,
#  'garag': 366,
#  'request': 367,
#  'time': 368,
#  'everyon': 369,
#  'workout': 370,
#  'equip': 371,
#  'leisur': 372,
#  'vehicl': 373,
#  'quit': 374,
#  'neibourhood': 375,
#  'kati': 376,
#  'lacentera': 377,
#  'movi': 378,
#  'grand': 379,
#  'parkway': 380,
#  'comfi': 381,
#  'light': 382,
#  'carriag': 383,
#  'distanc': 384,
#  'denton': 385,
#  'univers': 386,
#  'dcta': 387,
#  'bu': 388,
#  'train': 389,
#  'station': 390,
#  'kitchenett': 391,
#  'microwav': 392,
#  'refriger': 393,
#  'freezer': 394,
#  'pot': 395,
#  'murphi': 396,
#  'downstair': 397,
#  'loft': 398,
#  'air': 399,
#  'mattress': 400,
#  'pleas': 401,
#  'caution': 402,
#  'ladder': 403,
#  'stair': 404,
#  'chaletazul': 405,
#  '2rm': 406,
#  '4bd': 407,
#  '30day': 408,
#  'rent': 409,
#  'chalet': 410,
#  '6': 411,
#  'hottub': 412,
#  '18': 413,
#  '20': 414,
#  'sea': 415,
#  'world': 416,
#  'fiesta': 417,
#  'gruen': 418,
#  'braunfel': 419,
#  'onsit': 420,
#  'concierg': 421,
#  'medicin': 422,
#  'massag': 423,
#  'babysit': 424,
#  'discount': 425,
#  'king': 426,
#  'warm': 427,
#  'vacat': 428,
#  'extend': 429,
#  'childbirth': 430,
#  'tourist': 431,
#  'special': 432,
#  'talk': 433,
#  'spanish': 434,
#  'english': 435,
#  'french': 436,
#  'fabul': 437,
#  'tradit': 438,
#  'interior': 439,
#  'furnitur': 440,
#  'soco': 441,
#  'acl': 442,
#  'sxsw': 443,
#  'sola': 444,
#  'eateri': 445,
#  'bar': 446,
#  'larg': 447,
#  'doubl': 448,
#  'accommod': 449,
#  'free': 450,
#  'wifi': 451,
#  'reserv': 452,
#  'TH': 453,
#  'upstair': 454,
#  'commun': 455,
#  'seriou': 456,
#  'inquiri': 457,
#  'renov': 458,
#  'plano': 459,
#  'school': 460,
#  'around': 461,
#  'mind': 462,
#  'prepar': 463,
#  'everyth': 464,
#  'brand': 465,
#  'find': 466,
#  'hotel': 467,
#  'provid': 468,
#  'much': 469,
#  'high': 470,
#  'ultim': 471,
#  'fast': 472,
#  '200': 473,
#  'mbp': 474,
#  '55': 475,
#  'smart': 476,
#  'netflix': 477,
#  'local': 478,
#  'channel': 479,
#  'grill': 480,
#  'studi': 481,
#  'etc': 482,
#  'book': 483,
#  'couch': 484,
#  'surf': 485,
#  'rail': 486,
#  'goe': 487,
#  'apt': 488,
#  'fun': 489,
#  'five': 490,
#  'seven': 491,
#  'directli': 492,
#  'ballpark': 493,
#  'arlington': 494,
#  'hurrican': 495,
#  'harbor': 496,
#  'treed': 497,
#  'trail': 498,
#  'attract': 499,
#  'entir': 500,
#  '400': 501,
#  'sq': 502,
#  'ft': 503,
#  'attach': 504,
#  'desir': 505,
#  'tarrytown': 506,
#  '1940': 507,
#  'licens': 508,
#  'oper': 509,
#  'short': 510,
#  'term': 511,
#  'note': 512,
#  'occup': 513,
#  'tax': 514,
#  'star': 515,
#  'night': 516,
#  'bedrol': 517,
#  'bunkhous': 518,
#  'ranch': 519,
#  'nestl': 520,
#  '30': 521,
#  'landscap': 522,
#  'hors': 523,
#  'shoe': 524,
#  'pit': 525,
#  'gazz': 526,
#  'listen': 527,
#  'coyot': 528,
#  'sing': 529,
#  'sit': 530,
#  'read': 531,
#  'monro': 532,
#  'manor': 533,
#  'water': 534,
#  'style': 535,
#  'shiplap': 536,
#  'wall': 537,
#  'even': 538,
#  'better': 539,
#  'amethyst': 540,
#  'canyon': 541,
#  'venu': 542,
#  'poodi': 543,
#  'roadhous': 544,
#  'pace': 545,
#  'bend': 546,
#  'pedernal': 547,
#  'marbl': 548,
#  'fall': 549,
#  'hill': 550,
#  'api': 551,
#  'hike': 552,
#  'play': 553,
#  'launch': 554,
#  'boat': 555,
#  'ambianc': 556,
#  'dog': 557,
#  'cat': 558,
#  'properti': 559,
#  '1953': 560,
#  'spartanett': 561,
#  'guesthous': 562,
#  'modern': 563,
#  'spartan': 564,
#  'shade': 565,
#  'casa': 566,
#  'de': 567,
#  'alexi': 568,
#  'guesthom': 569,
#  'laid': 570,
#  'plenti': 571,
#  'caretak': 572,
#  'excel': 573,
#  'safeti': 574,
#  'goal': 575,
#  'wheel': 576,
#  'chair': 577,
#  'handicap': 578,
#  'shower': 579,
#  'w': 580,
#  'key': 581,
#  'low': 582,
#  'cost': 583,
#  'motel': 584,
#  'door': 585,
#  'lock': 586,
#  'schedul': 587,
#  'arriv': 588,
#  'may': 589,
#  'greet': 590,
#  'anytim': 591,
#  '1pm': 592,
#  'day': 593,
#  '24': 594,
#  '7': 595,
#  'keyless': 596,
#  'entri': 597,
#  'code': 598,
#  'info': 599,
#  'know': 600,
#  'detail': 601,
#  'email': 602,
#  'airbnb': 603,
#  'confirm': 604,
#  '100': 605,
#  'hassl': 606,
#  'bicker': 607,
#  'ST': 608,
#  'N': 609,
#  'westmoreland': 610,
#  'RD': 611,
#  '75212': 612,
#  'femal': 613,
#  'comal': 614,
#  'schlitterbahn': 615,
#  'hideway': 616,
#  'furnish': 617,
#  'unit': 618,
#  'take': 619,
#  'advantag': 620,
#  'along': 621,
#  'insid': 622,
#  'spectacular': 623,
#  'make': 624,
#  'next': 625,
#  'rememb': 626,
#  'eleg': 627,
#  'rest': 628,
#  '4k': 629,
#  'bigger': 630,
#  'fire': 631,
#  'complet': 632,
#  'readi': 633,
#  'brick': 634,
#  'per': 635,
#  'direct': 636,
#  '500': 637,
#  'watch': 638,
#  'sheet': 639,
#  'pillow': 640,
#  'case': 641,
#  'summon': 642,
#  'sanctuari': 643,
#  'abilen': 644,
#  'stylishli': 645,
#  'updat': 646,
#  'taylor': 647,
#  'counti': 648,
#  'expo': 649,
#  'shotwel': 650,
#  'zoo': 651,
#  'lyle': 652,
#  'land': 653,
#  'cattl': 654,
#  'finish': 655,
#  'standard': 656,
#  'valu': 657,
#  'prestig': 658,
#  'move': 659,
#  'bungalow': 660,
#  'craftsman': 661,
#  'ride': 662,
#  'bikeshar': 663,
#  'samuel': 664,
#  'ave': 665,
#  'connect': 666,
#  'point': 667,
#  'west': 668,
#  '7th': 669,
#  'district': 670,
#  'magnolia': 671,
#  'triniti': 672,
#  'track': 673,
#  'ambient': 674,
#  'nois': 675,
#  'ad': 676,
#  'year': 677,
#  'concept': 678,
#  'TX': 679,
#  'sleeper': 680,
#  'maximum': 681,
#  'descript': 682,
#  'singl': 683,
#  'pasadena': 684,
#  '21': 685,
#  'nrg': 686,
#  'allow': 687,
#  'suit': 688,
#  'june': 689,
#  'juli': 690,
#  'kyle': 691,
#  'georg': 692,
#  'bush': 693,
#  'librari': 694,
#  'northgat': 695,
#  'eat': 696,
#  'tidi': 697,
#  'mani': 698,
#  'reason': 699,
#  'person': 700,
#  'morn': 701,
#  'Br': 702,
#  'Ba': 703,
#  'orient': 704,
#  '75': 705,
#  '121': 706,
#  '45': 707,
#  'rang': 708,
#  'within': 709,
#  'premium': 710,
#  'outlet': 711,
#  'stonebriar': 712,
#  'watter': 713,
#  'parti': 714,
#  'hackberri': 715,
#  'total': 716,
#  'twin': 717,
#  'futon': 718,
#  'electr': 719,
#  'stove': 720,
#  'refrigeratior': 721,
#  'icemak': 722,
#  'toaster': 723,
#  'coffeepot': 724,
#  'utensil': 725,
#  'plate': 726,
#  'cookwar': 727,
#  'linen': 728,
#  'dish': 729,
#  'AC': 730,
#  'heat': 731,
#  'bandera': 732,
#  'smoke': 733,
#  'ferral': 734,
#  'fed': 735,
#  '2016': 736,
#  'stori': 737,
#  '2br': 738,
#  '70': 739,
#  'tv': 740,
#  'inflat': 741,
#  'groceri': 742,
#  'store': 743,
#  'hr': 744,
#  'emerg': 745,
#  'gym': 746,
#  'treadmil': 747,
#  'erg': 748,
#  'machin': 749,
#  'crate': 750,
#  'german': 751,
#  'shepherd': 752,
#  'limit': 753,
#  '1st': 754,
#  'convent': 755,
#  'hemisfair': 756,
#  'alamodom': 757,
#  'southtown': 758,
#  'array': 759,
#  'public': 760,
#  'basebal': 761,
#  'playground': 762,
#  'picnic': 763,
#  'intern': 764,
#  'bike': 765,
#  'rack': 766,
#  'block': 767,
#  'hwi': 768,
#  '69': 769,
#  'third': 770,
#  'offic': 771,
#  'work': 772,
#  'RV': 773,
#  'US': 774,
#  'NE': 775,
#  'medic': 776,
#  'kingwood': 777,
#  'monday': 778,
#  'thursday': 779,
#  'often': 780,
#  'except': 781,
#  'environ': 782,
#  'allianc': 783,
#  'i35': 784,
#  'look': 785,
#  'long': 786,
#  'student': 787,
#  'profession': 788,
#  'renter': 789,
#  '3br': 790,
#  '2B': 791,
#  'fantast': 792,
#  'bienvenido': 793,
#  'tailor': 794,
#  'proxim': 795,
#  'houston': 796,
#  'typhoon': 797,
#  'energi': 798,
#  'corridor': 799,
#  'hospit': 800,
#  'sincer': 801,
#  'profit': 802,
#  'dear': 803,
#  'la': 804,
#  'colina': 805,
#  'newli': 806,
#  'lit': 807,
#  'tub': 808,
#  'accompani': 809,
#  'surround': 810,
#  'background': 811,
#  'complimentari': 812,
#  '2min': 813,
#  'clara': 814,
#  'martin': 815,
#  'sunset': 816,
#  'clear': 817,
#  'everi': 818,
#  'bring': 819,
#  'kayak': 820,
#  'jet': 821,
#  'ski': 822,
#  '40': 823,
#  'slip': 824,
#  'afford': 825,
#  'med': 826,
#  'spare': 827,
#  'hermann': 828,
#  'rice': 829,
#  'nearest': 830,
#  'toiletri': 831,
#  'culdasec': 832,
#  'colleg': 833,
#  'borderlin': 834,
#  'boast': 835,
#  'spaciou': 836,
#  'tile': 837,
#  'counter': 838,
#  'breakfast': 839,
#  'enough': 840,
#  'quick': 841,
#  'either': 842,
#  'tanglewood': 843,
#  'splashpad': 844,
#  'effect': 845,
#  'basic': 846,
#  'applianc': 847,
#  'silverwar': 848,
#  'cook': 849,
#  'ware': 850,
#  'glass': 851,
#  'unwind': 852,
#  'ton': 853,
#  'poolsid': 854,
#  'regist': 855,
#  'saltwat': 856,
#  'jacuzzi': 857,
#  'pm': 858,
#  'start': 859,
#  'jog': 860,
#  'game': 861,
#  'tenni': 862,
#  'basketbal': 863,
#  'fill': 864,
#  'healthi': 865,
#  'lifestyl': 866,
#  'blanco': 867,
#  'concan': 868,
#  'hole': 869,
#  'highest': 870,
#  '4342': 871,
#  'livabl': 872,
#  '28': 873,
#  'level': 874,
#  '635': 875,
#  'garland': 876,
#  'mesquit': 877,
#  'pictur': 878,
#  'hanger': 879,
#  'chiffarob': 880,
#  'shelv': 881,
#  'chest': 882,
#  'drawer': 883,
#  '60': 884,
#  'treehous': 885,
#  'oasi': 886,
#  'actual': 887,
#  '2nd': 888,
#  'lamin': 889,
#  'perk': 890,
#  'self': 891,
#  'trundl': 892,
#  'traffic': 893,
#  'establish': 894,
#  'IH': 895,
#  'bamc': 896,
#  'uthscsa': 897,
#  'anyon': 898,
#  'emerald': 899,
#  'gem': 900,
#  'among': 901,
#  'old': 902,
#  'growth': 903,
#  'oak': 904,
#  'potter': 905,
#  'weekend': 906,
#  'spot': 907,
#  'decompress': 908,
#  'import': 909,
#  'scent': 910,
#  'cedar': 911,
#  'reinvigor': 912,
#  'crystal': 913,
#  'call': 914,
#  'name': 915,
#  'strateg': 916,
#  'hour': 917,
#  'wimberley': 918,
#  'fredericksburg': 919,
#  'word': 920,
#  'CC': 921,
#  'shadow': 922,
#  'glen': 923,
#  'week': 924,
#  'longer': 925,
#  'other': 926,
#  'beverag': 927,
#  'fellowship': 928,
#  'condominium': 929,
#  'might': 930,
#  'victorian': 931,
#  'farmhous': 932,
#  'delight': 933,
#  'ensuit': 934,
#  'pc': 935,
#  'keurig': 936,
#  'roll': 937,
#  'squar': 938,
#  'mckinney': 939,
#  'known': 940,
#  'vibrant': 941,
#  'testament': 942,
#  'money': 943,
#  'magazin': 944,
#  'rate': 945,
#  '2bdr': 946,
#  '2bath': 947,
#  'woodland': 948,
#  '12hp02': 949,
#  'execut': 950,
#  '1200': 951,
#  'anybodi': 952,
#  'would': 953,
#  'delici': 954,
#  'meal': 955,
#  'dramat': 956,
#  'nine': 957,
#  'foot': 958,
#  'ceram': 959,
#  'custom': 960,
#  'trim': 961,
#  'crown': 962,
#  'mold': 963,
#  'fan': 964,
#  'comput': 965,
#  'desk': 966,
#  'overs': 967,
#  'expans': 968,
#  'gameday': 969,
#  'sleepov': 970,
#  'tamu': 971,
#  'superbowl': 972,
#  'multipl': 973,
#  'hobbi': 974,
#  'walmart': 975,
#  'furri': 976,
#  'semi': 977,
#  'meadow': 978,
#  'euless': 979,
#  'Ft': 980,
#  'cowboy': 981,
#  'ranger': 982,
#  'charg': 983,
#  'fee': 984,
#  'burnet': 985,
#  'brentwood': 986,
#  'found': 987,
#  'pad': 988,
#  'stone': 989,
#  'throw': 990,
#  'transit': 991,
#  'sever': 992,
#  'lala': 993,
#  'famou': 994,
#  'christma': 995,
#  'pour': 996,
#  'aristocrat': 997,
#  'notch': 998,
#  'stubb': 999,
#  ...}
